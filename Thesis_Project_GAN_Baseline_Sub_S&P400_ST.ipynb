# %% [markdown]
# <a href="https://colab.research.google.com/github/Freddy-94/Thesis_Project_GAN/blob/main/Thesis_Project_GAN_Baseline_Sub_S%26P400_ST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Alfredo Bernal Luna
# ### December 22nd 2024
# ### GAN implementation to forecast stock market prices (Sigmoid activation version - S&P400 Index subset - Rolling mean and max-min scaling over a window of 20 days - Same time for historic prices)
#
# In this project, we define a GAN architecture with a three-layer dense network as the generator, and a three-layer CNN as the discriminator.
#
# The **Generator** uses three fully connected (Dense) layers:
#
# 1.   First layer: The Input dimension is 'generator_input_size', with output size scaled by a factor of 10 of 'generator_output_size'.
# 2.   Second layer: Output size scaled by a factor of 5 of 'generator_output_size'.
# 3. Third layer: Output matches the required size of (num_historical_days, num_features) after reshaping.
#
# The **Discriminator** uses three convolutional layers:
#
# 1. First Conv2D layer: 32 filters with a kernel size of (3,1) and ReLU activation.
# 2. Second Conv2D layer: 64 filters with ReLU activation.
# 3. Third Conv2D layer: 128 filters followed by a fully connected layer and sigmoid activation for the output.
#
# Our GAN model will generate synthetic features from stock price data, which will be then used as inputs for an XGBoost model to predict stock price movements. The XGBoost model is used to perform classification to predict whether stock prices will go up or down after a certain number of days (defined by the constant 'DAYS_AHEAD').
#
# The features for XGBoost are GAN-generated synthetic stock sequences flattened to 1D arrays, and the labels are computed based on the percent change in the stock's closing price over a given time horizon (in our case, 1 day ahead). If the percent change is greater than the threshold 'pct_change', the label is 1 (indicating an upward movement), otherwise, it is 0 (indicating a downward movement).
#
# The XGBoost model is trained to predict these labels, i.e., whether the stock price will go up or down based on the features generated by the GAN.
#
# **Data Flow and Preprocessing**:
#
# *   Training Data:
#   1.   The raw stock data is normalized using rolling mean and max-min scaling over a window of num_historical_days.
#   2.   We split the dataset into training and test sets. For training, the GAN generates synthetic sequences for the training set, which are used as inputs for XGBoost. The labels for training are derived from the actual stock price movements.
#
# *   Test Data:
#   1.  Similar to the training data, we use the GAN to generate synthetic stock data sequences for the test set. These synthetic sequences serve as input for the XGBoost model during evaluation.
#   2.   The test labels are derived from the real stock data’s price movements (percent change over 1 day).
#
# **XGBoost Training and Evaluation**:
#
# We train the XGBoost model with the GAN-generated features using a softmax objective for binary classification (i.e., whether the stock price will go up or down), and track performance using the mlogloss metric. Further, we perform early stopping based on the evaluation on the test set.
#
# After the training, the model's predictions on the test set are compared to the actual labels (up/down movements). We use a confusion matrix to evaluate the model’s accuracy, measuring how well the XGBoost model, trained on GAN-generated features, is able to predict stock price movements.
#
# **GAN-XGBoost Combination achievments**:
#
# The combination of GAN and XGBoost in this project serves two main purposes:
#
# 1.   **Synthetic Data Generation**: The GAN generates synthetic stock price data sequences that capture realistic market patterns, potentially providing better input features for prediction.
# 2.   **Stock Price Movement Prediction**: XGBoost uses these synthetic sequences to predict whether the stock price will rise or fall after a given time frame, based on the historical patterns captured by the GAN.

# %% [markdown]
# ### To mount your Google Drive to the Colab environment

# %%
# GOOGLE DRIVE - COLAB
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
# drive.mount('/content/drive')
drive.mount("/content/drive", force_remount=True)

# After executing the line above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Global variables used in the project

# %%
# googlepath exists for googledrive finding the files.
# Have companylist.csv in same dir. Will create
# a stock_data folder and download stocks data into it.
googlepath = "drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/"

# Setting the Training Amount
TRAINING_AMOUNT = 50000 # 50000
SAVE_STEPS_AMOUNT = 10000 # testing for now
PCT_CHANGE_AMOUNT = 0.001 # just want to see up down trends ORIGINAL 5
HISTORICAL_DAYS_AMOUNT = 20
DAYS_AHEAD = 1 # ORIGINAL 5

# %% [markdown]
# ### Get data from Alpha Vantage

# %%
'''
Download stock data from alphavantage
'''
import pandas as pd
import os
import time
import urllib
import json
import csv
import requests
import io
from pathlib import Path
import random

ALPHA_VANTAGE_KEY = "XXXXXXXXXX"

'''
Saves data to a file
'''
def save(googlepath, stock_csv, output_dir, filename):
    try:
        output_path = os.path.join(googlepath, output_dir)
        if not os.path.exists(output_path):
            os.makedirs(output_path)

        filepath = os.path.join(output_path, filename)

        if not stock_csv.empty:
            if 'timestamp' in stock_csv.columns:
                stock_csv = stock_csv.sort_values(by='timestamp')
            stock_csv.to_csv(filepath, index=False)
            print(f"Saved data to {filepath}")
        else:
            print(f"DataFrame is empty for {filename}. Nothing to save.")
    except Exception as ex:
        print(f'Could not open file {filepath} to write data')
        print(ex)

def try_download(symbol):
    try:
        time.sleep(12)
        url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&apikey={ALPHA_VANTAGE_KEY}&datatype=csv&outputsize=full'
        c = pd.read_csv(url)
        if c.empty:
            raise ValueError(f"No data fetched for {symbol}")
        return c, True
    except Exception as ex:
        print(f"Error fetching data for {symbol}: {ex}")
        return None, None

#Given a stock symbol (aka 'goog') will download and save the data to the
#output dir as a csv

def download_symbol(symbol, output_dir, retry_count=4):
    stock_csv, didPass = try_download(symbol)
    if didPass:
        save(googlepath, stock_csv, output_dir, '{}.csv'.format(symbol))
    else:
        print('Failed to download {}'.format(symbol))


df = pd.read_csv(f"{googlepath}/companylist.csv")
for symbol in df.Symbol:
    my_file = Path(f"{googlepath}/stock_data/{symbol}.csv")  # check if already downloaded
    if not my_file.exists():
        print('Downloading {}'.format(symbol))
        download_symbol(symbol, 'stock_data')
    else:
        print(f"Already downloaded {symbol}")
# Out:
# Already downloaded AAON
# Already downloaded ACHC
# Already downloaded ADC
# Already downloaded AFG
# Already downloaded AGCO
# Already downloaded AIT
# Already downloaded ALE
# Already downloaded ALV
# Already downloaded AMED
# Already downloaded AMG
# Already downloaded AMKR
# Already downloaded AN
# Already downloaded ANF
# Already downloaded ARW
# Already downloaded ARWR
# Already downloaded ASB
# Already downloaded ASGN
# Already downloaded ASH
# Already downloaded ATR
# Already downloaded AVNT
# Already downloaded AVT
# Already downloaded AZPN
# Already downloaded AZTA
# Already downloaded BC
# Already downloaded BCO
# Already downloaded BDC
# Already downloaded BIO
# Already downloaded BKH
# Already downloaded BMRN
# Already downloaded BYD
# Already downloaded CACI
# Already downloaded CADE
# Already downloaded CAR
# Already downloaded CASY
# Already downloaded CBSH
# Already downloaded CBT
# Already downloaded CCK
# Already downloaded CDP
# Already downloaded CFR
# Already downloaded CGNX
# Already downloaded CHDN
# Already downloaded CHE
# Already downloaded CHH
# Already downloaded CIEN
# Already downloaded CLF
# Already downloaded CLH
# Already downloaded CMC
# Already downloaded CNX
# Already downloaded COHR
# Already downloaded COKE
# Already downloaded COLB
# Already downloaded COLM
# Already downloaded CRUS
# Already downloaded CSL
# Already downloaded CUZ
# Already downloaded CW
# Already downloaded CXT
# Already downloaded DAR
# Already downloaded DCI
# Already downloaded DINO
# Already downloaded EEFT
# Already downloaded EGP
# Already downloaded ELS
# Already downloaded EME
# Already downloaded EPR
# Already downloaded EWBC
# Already downloaded EXP
# Already downloaded EXPO
# Already downloaded FCFS
# Already downloaded FCN
# Already downloaded FFIN
# Already downloaded FHI
# Already downloaded FHN
# Already downloaded FIX
# Already downloaded FLO
# Already downloaded FLS
# Already downloaded FNB
# Already downloaded FR
# Already downloaded GAP
# Already downloaded GATX
# Already downloaded GBCI
# Already downloaded GEF
# Already downloaded GGG
# Already downloaded GHC
# Already downloaded GNTX
# Already downloaded GPK
# Already downloaded GT
# Already downloaded HAE
# Already downloaded HOG
# Already downloaded HR
# Already downloaded HRB
# Already downloaded HXL
# Already downloaded IBOC
# Already downloaded IDA
# Already downloaded INGR
# Already downloaded ITT
# Already downloaded JEF
# Already downloaded JLL
# Already downloaded JWN
# Already downloaded KBH
# Already downloaded KEX
# Already downloaded KMPR
# Already downloaded KNX
# Already downloaded KRC
# Already downloaded LAD
# Already downloaded LAMR
# Already downloaded LANC
# Already downloaded LECO
# Already downloaded LFUS
# Already downloaded LII
# Already downloaded LNW
# Already downloaded LPX
# Already downloaded LSCC
# Already downloaded LSTR
# Already downloaded M
# Already downloaded MAN
# Already downloaded MANH
# Already downloaded MAT
# Already downloaded MIDD
# Already downloaded MKSI
# Already downloaded MMS
# Already downloaded MSA
# Already downloaded MSM
# Already downloaded MTG
# Already downloaded MTN
# Already downloaded MTZ
# Already downloaded MUR
# Already downloaded NBIX
# Already downloaded NEOG
# Already downloaded NEU
# Already downloaded NFG
# Already downloaded NJR
# Already downloaded NLY
# Already downloaded NNN
# Already downloaded NOV
# Already downloaded NSP
# Already downloaded FLG
# Already downloaded NYT
# Already downloaded OGE
# Already downloaded OHI
# Already downloaded OLED
# Already downloaded OLN
# Already downloaded ONB
# Already downloaded ONTO
# Already downloaded OPCH
# Already downloaded ORI
# Already downloaded OSK
# Already downloaded PAG
# Already downloaded PB
# Already downloaded PCH
# Already downloaded PII
# Already downloaded TXNM
# Already downloaded POWI
# Already downloaded PPC
# Already downloaded PRGO
# Already downloaded PVH
# Already downloaded R
# Already downloaded RBA
# Already downloaded RGEN
# Already downloaded RGLD
# Already downloaded RLI
# Already downloaded RMBS
# Already downloaded RNR
# Already downloaded RPM
# Already downloaded RRC
# Already downloaded RRX
# Already downloaded RS
# Already downloaded RYN
# Already downloaded SAM
# Already downloaded SCI
# Already downloaded SEIC
# Already downloaded SF
# Already downloaded SIGI
# Already downloaded SKX
# Already downloaded SLGN
# Already downloaded SLM
# Already downloaded SMG
# Already downloaded SNV
# Already downloaded SON
# Already downloaded SR
# Already downloaded SRPT
# Already downloaded SSB
# Already downloaded SSD
# Already downloaded SWX
# Already downloaded TEX
# Already downloaded THC
# Already downloaded THG
# Already downloaded THO
# Already downloaded TKR
# Already downloaded TOL
# Already downloaded TPL
# Already downloaded TREX
# Already downloaded TTC
# Already downloaded TTEK
# Already downloaded UBSI
# Already downloaded UFPI
# Already downloaded UGI
# Already downloaded UMBF
# Already downloaded UNM
# Already downloaded UTHR
# Already downloaded VAL
# Already downloaded VLY
# Already downloaded VMI
# Already downloaded VNO
# Already downloaded VSH
# Already downloaded WBS
# Already downloaded WCC
# Already downloaded WEN
# Already downloaded WHR
# Already downloaded WPC
# Already downloaded WSM
# Already downloaded WSO
# Already downloaded WTFC
# Already downloaded WTRG
# Already downloaded WTS
# Already downloaded WWD
# Already downloaded X
# Already downloaded XRAY
# Already downloaded ZION

# %% [markdown]
# ### Confusion Matrix definition

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.ylim([1.5, -.5])


    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    #thresh = cm.max() / 2. # Previous
    fmt = '.4f' if normalize else 'd'
    thresh = cm.max() - 0.05

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        #print (cm[i, j])
        plt.text(j, i, format(cm[i, j],fmt),
                 horizontalalignment="center",
                 fontsize=24,
                 color="white" if cm[i, j] > thresh else "black")

    #for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    #    plt.text(j, i, cm[i, j],
    #             horizontalalignment="center",
    #             color="black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# ### Initializing the GAN definition

# %%
import tensorflow as tf
import numpy as np

class GAN(tf.keras.Model):
    def __init__(self, num_features, num_historical_days, generator_input_size=200, is_train=True):
        super(GAN, self).__init__()
        self.num_features = num_features
        self.num_historical_days = num_historical_days
        self.generator_input_size = generator_input_size
        self.is_train = is_train

        # Build generator and discriminator
        self.generator = self.build_generator()
        self.discriminator = self.build_discriminator()

    def sample_Z(self, batch_size, n):
        return np.random.uniform(-1., 1., size=(batch_size, n))

    def build_generator(self):
        model = tf.keras.Sequential()
        generator_output_size = self.num_features * self.num_historical_days

        model.add(tf.keras.layers.Dense(generator_output_size * 10, input_dim=self.generator_input_size))
        model.add(tf.keras.layers.Activation('sigmoid'))

        model.add(tf.keras.layers.Dense(generator_output_size * 5))
        model.add(tf.keras.layers.Activation('sigmoid'))

        model.add(tf.keras.layers.Dense(generator_output_size))
        model.add(tf.keras.layers.Reshape((self.num_historical_days, self.num_features)))

        return model

    def build_discriminator(self):
        model = tf.keras.Sequential()

        model.add(tf.keras.layers.Conv2D(32, (3, 1), input_shape=(self.num_historical_days, 1, self.num_features), padding='same'))
        model.add(tf.keras.layers.ReLU())  # Use ReLU activation
        if self.is_train:
            model.add(tf.keras.layers.Dropout(0.3))

        model.add(tf.keras.layers.Conv2D(64, (3, 1), padding='same'))
        model.add(tf.keras.layers.ReLU())  # Use ReLU activation
        if self.is_train:
            model.add(tf.keras.layers.Dropout(0.3))

        model.add(tf.keras.layers.Conv2D(128, (3, 1), padding='valid'))
        model.add(tf.keras.layers.ReLU())  # Use ReLU activation
        if self.is_train:
            model.add(tf.keras.layers.Dropout(0.3))

        model.add(tf.keras.layers.Flatten())
        model.add(tf.keras.layers.Dense(128))
        model.add(tf.keras.layers.ReLU())  # Use ReLU activation
        model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

        return model

    def call(self, inputs, training=False):
        noise, real_data = inputs
        generated_data = self.generator(noise, training=training)
        generated_data = tf.reshape(generated_data, [-1, self.num_historical_days, 1, self.num_features])
        real_data = tf.reshape(real_data, [-1, self.num_historical_days, 1, self.num_features])

        real_output = self.discriminator(real_data, training=training)
        fake_output = self.discriminator(generated_data, training=training)

        return real_output, fake_output, generated_data

# %% [markdown]
# ### Tensorflow version

# %%
print("TensorFlow version: {}".format(tf.__version__))
print("Eager execution is: {}".format(tf.executing_eagerly()))
# Out:
# TensorFlow version: 2.17.1
# Eager execution is: True

# %% [markdown]
# ### Training the GAN

# %%
import tensorflow as tf
import numpy as np
import random
import os
import pandas as pd
import matplotlib.pyplot as plt

random.seed(24)

class TrainGan:
    def __init__(self, num_historical_days, batch_size=128):
        self.batch_size = batch_size
        self.data = []

        files = [f"{googlepath}stock_data/{f}" for f in os.listdir(f"{googlepath}stock_data")]

        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df[['open', 'high', 'low', 'close', 'volume']]

            df = ((df -
                   df.rolling(num_historical_days).mean().shift(-num_historical_days))
                  / (df.rolling(num_historical_days).max().shift(-num_historical_days)
                     - df.rolling(num_historical_days).min().shift(-num_historical_days)))

            df = df.dropna()
            df = df[400:]

            for i in range(num_historical_days, len(df), num_historical_days):
                self.data.append(df.values[i-num_historical_days:i])

        self.gan = GAN(num_features=5, num_historical_days=num_historical_days,
                       generator_input_size=200)

        # Optimizers
        self.G_optimizer = tf.keras.optimizers.Adam(learning_rate=0.000055)  #  0.0001
        self.D_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)   #  0.0004

        # Initialize lists for loss tracking
        self.g_loss_array = []
        self.d_loss_array = []

    def random_batch(self, batch_size=128):
        batch = []
        while True:
            batch.append(random.choice(self.data))
            if len(batch) == batch_size:
                yield batch
                batch = []

    def train(self, print_steps=100, display_data=100, save_steps=1000):
        if not os.path.exists(f'{googlepath}models'):
            os.makedirs(f'{googlepath}models')

        current_step = 0

        for i, X in enumerate(self.random_batch(self.batch_size)):
            noise = self.gan.sample_Z(self.batch_size, 200)

            with tf.GradientTape() as tape:
                D_real, D_fake, _ = self.gan((noise, X), training=True)
                D_loss_real = tf.keras.losses.BinaryCrossentropy()(tf.ones_like(D_real), D_real)
                D_loss_fake = tf.keras.losses.BinaryCrossentropy()(tf.zeros_like(D_fake), D_fake)
                D_loss = D_loss_real + D_loss_fake

            grads = tape.gradient(D_loss, self.gan.discriminator.trainable_variables)
            self.D_optimizer.apply_gradients(zip(grads, self.gan.discriminator.trainable_variables))

            with tf.GradientTape() as tape:
                _, D_fake, _ = self.gan((noise, X), training=True)
                G_loss = tf.keras.losses.BinaryCrossentropy()(tf.ones_like(D_fake), D_fake)

            grads = tape.gradient(G_loss, self.gan.generator.trainable_variables)
            self.G_optimizer.apply_gradients(zip(grads, self.gan.generator.trainable_variables))

            # Record losses
            self.g_loss_array.append(G_loss.numpy())
            self.d_loss_array.append(D_loss.numpy())

            if (i + 1) % print_steps == 0:
                print(f'Step={i + current_step} D_loss={D_loss.numpy()} G_loss={G_loss.numpy()}')

            if (i + 1) % save_steps == 0:
                self.gan.save_weights(f'{googlepath}/models/gan.weights.h5')

            if ((i + current_step) > TRAINING_AMOUNT):
                print(f"Reached {i + current_step} epochs for GAN")
                break

        # Plot the losses
        self.plot_losses()

    def plot_losses(self):
        plt.figure(figsize=(12, 6))

        # Plot generator loss
        plt.subplot(1, 2, 1)
        plt.plot(self.g_loss_array, label='Generator Loss')
        plt.title('Generator Loss')
        plt.xlabel('Steps')
        plt.ylabel('Loss')
        plt.legend()

        # Plot discriminator loss
        plt.subplot(1, 2, 2)
        plt.plot(self.d_loss_array, label='Discriminator Loss')
        plt.title('Discriminator Loss')
        plt.xlabel('Steps')
        plt.ylabel('Loss')
        plt.legend()

        plt.tight_layout()
        plt.show()

gan = TrainGan(HISTORICAL_DAYS_AMOUNT, 128)
gan.train()
# Out:
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VNO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WSM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WWD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TXNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UMBF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WPC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UFPI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WSO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VMI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WTS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TTEK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/X.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VSH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WCC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UTHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TOL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TREX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VAL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UBSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WTRG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/XRAY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ZION.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/THC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WTFC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SRPT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TPL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WBS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/THG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/THO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SWX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TTC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SON.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SAM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UGI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SLM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SLGN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SNV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RMBS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RRX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SEIC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RNR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RGLD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RGEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SIGI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RYN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SKX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SSB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ONTO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PRGO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/R.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/POWI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RLI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PII.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RBA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PAG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PCH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RRC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NNN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OLED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RPM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NYT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OSK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NSP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OHI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PVH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NOV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PPC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MTN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MTZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MSM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OPCH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SSD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NJR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OLN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OGE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NBIX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NEU.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MKSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ONB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MIDD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MAT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MSA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ORI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MMS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/M.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NEOG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NFG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LPX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MANH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MUR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LSTR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LSCC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MTG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KRC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/JEF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LANC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MAN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LFUS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ITT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/IBOC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LNW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/IDA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LII.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KMPR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LECO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KBH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GPK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/JLL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/INGR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GEF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GBCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LAD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GGG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HAE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/JWN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HXL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HOG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FCN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HRB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GNTX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FNB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FLG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FLO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LAMR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FCFS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EPR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FHN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FHI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EME.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EXPO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EGP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FIX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CRUS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EXP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/DINO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EWBC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/DCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CUZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/DAR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FLS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CSL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ELS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/COLB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FFIN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/COLM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GATX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CDP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CLF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EEFT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CMC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CXT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CHE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CASY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CLH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CGNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GAP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CACI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CIEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CAR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CADE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CBT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/COHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CFR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AGCO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BIO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CBSH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BDC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AVT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ATR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BCO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CHDN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BKH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BYD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BMRN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AZPN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ASGN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AMKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ARWR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AZTA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ASH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/COKE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CHH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ARW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ADC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AMED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AAON.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AFG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ACHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ASB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CCK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AIT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ALE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AVNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ANF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ALV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AN.csv
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Step=99 D_loss=1.0752967596054077 G_loss=1.4404735565185547
# Step=199 D_loss=1.1406030654907227 G_loss=0.9566099047660828
# Step=299 D_loss=1.318630576133728 G_loss=1.0433845520019531
# Step=399 D_loss=1.2455929517745972 G_loss=0.6374986171722412
# Step=499 D_loss=nan G_loss=nan
# Step=599 D_loss=nan G_loss=nan
# Step=699 D_loss=nan G_loss=nan
# Step=799 D_loss=nan G_loss=nan
# Step=899 D_loss=nan G_loss=nan
# Step=999 D_loss=nan G_loss=nan
# Step=1099 D_loss=nan G_loss=nan
# Step=1199 D_loss=nan G_loss=nan
# Step=1299 D_loss=nan G_loss=nan
# Step=1399 D_loss=nan G_loss=nan
# Step=1499 D_loss=nan G_loss=nan
# Step=1599 D_loss=nan G_loss=nan
# Step=1699 D_loss=nan G_loss=nan
# Step=1799 D_loss=nan G_loss=nan
# Step=1899 D_loss=nan G_loss=nan
# Step=1999 D_loss=nan G_loss=nan
# Step=2099 D_loss=nan G_loss=nan
# Step=2199 D_loss=nan G_loss=nan
# Step=2299 D_loss=nan G_loss=nan
# Step=2399 D_loss=nan G_loss=nan
# Step=2499 D_loss=nan G_loss=nan
# Step=2599 D_loss=nan G_loss=nan
# Step=2699 D_loss=nan G_loss=nan
# Step=2799 D_loss=nan G_loss=nan
# Step=2899 D_loss=nan G_loss=nan
# Step=2999 D_loss=nan G_loss=nan
# Step=3099 D_loss=nan G_loss=nan
# Step=3199 D_loss=nan G_loss=nan
# Step=3299 D_loss=nan G_loss=nan
# Step=3399 D_loss=nan G_loss=nan
# Step=3499 D_loss=nan G_loss=nan
# Step=3599 D_loss=nan G_loss=nan
# Step=3699 D_loss=nan G_loss=nan
# Step=3799 D_loss=nan G_loss=nan
# Step=3899 D_loss=nan G_loss=nan
# Step=3999 D_loss=nan G_loss=nan
# Step=4099 D_loss=nan G_loss=nan
# Step=4199 D_loss=nan G_loss=nan
# Step=4299 D_loss=nan G_loss=nan
# Step=4399 D_loss=nan G_loss=nan
# Step=4499 D_loss=nan G_loss=nan
# Step=4599 D_loss=nan G_loss=nan
# Step=4699 D_loss=nan G_loss=nan
# Step=47399 D_loss=nan G_loss=nan
# Step=47499 D_loss=nan G_loss=nan
# Step=47599 D_loss=nan G_loss=nan
# Step=47699 D_loss=nan G_loss=nan
# Step=47799 D_loss=nan G_loss=nan
# Step=47899 D_loss=nan G_loss=nan
# Step=47999 D_loss=nan G_loss=nan
# Step=48099 D_loss=nan G_loss=nan
# Step=48199 D_loss=nan G_loss=nan
# Step=48299 D_loss=nan G_loss=nan
# Step=48399 D_loss=nan G_loss=nan
# Step=48499 D_loss=nan G_loss=nan
# Step=48599 D_loss=nan G_loss=nan
# Step=48699 D_loss=nan G_loss=nan
# Step=48799 D_loss=nan G_loss=nan
# Step=48899 D_loss=nan G_loss=nan
# Step=48999 D_loss=nan G_loss=nan
# Step=49099 D_loss=nan G_loss=nan
# Step=49199 D_loss=nan G_loss=nan
# Step=49299 D_loss=nan G_loss=nan
# Step=49399 D_loss=nan G_loss=nan
# Step=49499 D_loss=nan G_loss=nan
# Step=49599 D_loss=nan G_loss=nan
# Step=49699 D_loss=nan G_loss=nan
# Step=49799 D_loss=nan G_loss=nan
# Step=49899 D_loss=nan G_loss=nan
# Step=49999 D_loss=nan G_loss=nan
# Reached 50001 epochs for GAN

# %% [markdown]
# ### Train XGB Boost

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import xgboost as xgb
from sklearn.metrics import confusion_matrix
from joblib import dump

class TrainXGBBoost:
    def __init__(self, num_historical_days, days=10, pct_change=0):
        self.data = []
        self.labels = []
        self.test_data = []
        self.test_labels = []

        # Initialize GAN model
        checkpoint_path = f'{googlepath}models/checkpoint'
        self.gan = GAN(num_features=5, num_historical_days=num_historical_days,
                       generator_input_size=200, is_train=False)

        if os.path.exists(checkpoint_path):
            self.gan.load_weights(f'{googlepath}/models/gan.weights.h5')
        else:
            print(f"No checkpoint found at {checkpoint_path}. Proceeding without it.")

        # Load and preprocess stock data
        files = [os.path.join(f'{googlepath}stock_data', f) for f in os.listdir(f'{googlepath}/stock_data')]
        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df[['open', 'high', 'low', 'close', 'volume']]

            # Compute labels
            labels = df.close.pct_change(days).map(lambda x: int(x > pct_change / 100.0))
            # Check class distribution    NEW LINE
            label_counts = labels.value_counts()  # NEW LINE
            print(f"Class distribution: \n{label_counts}") # NEW LINE
            df = ((df -
                   df.rolling(num_historical_days).mean().shift(-num_historical_days))
                  / (df.rolling(num_historical_days).max().shift(-num_historical_days)
                     - df.rolling(num_historical_days).min().shift(-num_historical_days)))
            df['labels'] = labels

            df = df.dropna()

            # Split into training and testing data
            test_df = df[:365]
            df = df[400:]

            data = df[['open', 'high', 'low', 'close', 'volume']].values
            labels = df['labels'].values

            noise_dim = 200
            for i in range(num_historical_days, len(df), num_historical_days):
                noise = tf.random.normal([1, noise_dim])
                features = self.gan.generator.predict(noise)

                # Flatten the features to 1D array
                self.data.append(features[0].flatten())
                self.labels.append(labels[i-1])

            data = test_df[['open', 'high', 'low', 'close', 'volume']].values
            labels = test_df['labels'].values
            for i in range(num_historical_days, len(test_df), 1):
                noise = tf.random.normal([1, noise_dim])
                features = self.gan.generator.predict(noise)

                # Flatten the features to 1D array
                self.test_data.append(features[0].flatten())
                self.test_labels.append(labels[i-1])

    def train(self):
        params = {
            'objective': 'multi:softprob',
            'eta': 0.01,
            'num_class': 2,
            'max_depth': 20,
            'subsample': 0.05,
            'colsample_bytree': 0.05,
            'eval_metric': 'mlogloss'
        }

        # Convert lists to numpy arrays for xgboost DMatrix
        train_data = xgb.DMatrix(np.array(self.data), label=np.array(self.labels))
        test_data = xgb.DMatrix(np.array(self.test_data), label=np.array(self.test_labels))

        watchlist = [(train_data, 'train'), (test_data, 'test')]
        clf = xgb.train(params, train_data, 1000, evals=watchlist, early_stopping_rounds=100)

        # Save the model
        dump(clf, f'{googlepath}models/clf.pkl')

        # Predict and compute confusion matrix
        predictions = clf.predict(test_data)
        cm = confusion_matrix(self.test_labels, list(map(lambda x: int(x[1] > .5), predictions)))
        print(cm)

        # Plot confusion matrix if necessary
        plot_confusion_matrix(cm, ['Down', 'Up'], normalize=True, title="Confusion Matrix")

        # Feature importance
        importance = clf.get_score(importance_type='weight')
        importance = sorted(importance.items(), key=lambda x: x[1], reverse=True)
        print("Feature importance (by weight):", importance)

        # Plot feature importance
        xgb.plot_importance(clf)
        plt.show()

# Example usage:
boost_model = TrainXGBBoost(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
boost_model.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Streaming output truncated to the last 5000 lines.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CCK.csv
# Class distribution:
# close
# 1    3175
# 0    3113
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AIT.csv
# Class distribution:
# close
# 1    3211
# 0    3077
# Name: count, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [0]	train-mlogloss:0.69287	test-mlogloss:0.69313
# [1]	train-mlogloss:0.69262	test-mlogloss:0.69311
# [2]	train-mlogloss:0.69241	test-mlogloss:0.69307
# [3]	train-mlogloss:0.69214	test-mlogloss:0.69304
# [4]	train-mlogloss:0.69190	test-mlogloss:0.69300
# [5]	train-mlogloss:0.69165	test-mlogloss:0.69296
# [6]	train-mlogloss:0.69141	test-mlogloss:0.69293
# [7]	train-mlogloss:0.69114	test-mlogloss:0.69290
# [8]	train-mlogloss:0.69092	test-mlogloss:0.69287
# [9]	train-mlogloss:0.69065	test-mlogloss:0.69281
# [10]	train-mlogloss:0.69041	test-mlogloss:0.69279
# [11]	train-mlogloss:0.69014	test-mlogloss:0.69277
# [12]	train-mlogloss:0.68986	test-mlogloss:0.69274
# [13]	train-mlogloss:0.68961	test-mlogloss:0.69272
# [14]	train-mlogloss:0.68938	test-mlogloss:0.69269
# [15]	train-mlogloss:0.68913	test-mlogloss:0.69265
# [16]	train-mlogloss:0.68887	test-mlogloss:0.69260
# [17]	train-mlogloss:0.68862	test-mlogloss:0.69257
# [18]	train-mlogloss:0.68835	test-mlogloss:0.69252
# [19]	train-mlogloss:0.68807	test-mlogloss:0.69247
# [20]	train-mlogloss:0.68781	test-mlogloss:0.69244
# [21]	train-mlogloss:0.68759	test-mlogloss:0.69240
# [22]	train-mlogloss:0.68738	test-mlogloss:0.69237
# [23]	train-mlogloss:0.68710	test-mlogloss:0.69233
# [24]	train-mlogloss:0.68689	test-mlogloss:0.69230
# [25]	train-mlogloss:0.68665	test-mlogloss:0.69231
# [26]	train-mlogloss:0.68645	test-mlogloss:0.69229
# [27]	train-mlogloss:0.68622	test-mlogloss:0.69224
# [28]	train-mlogloss:0.68598	test-mlogloss:0.69220
# [29]	train-mlogloss:0.68575	test-mlogloss:0.69218
# [30]	train-mlogloss:0.68548	test-mlogloss:0.69217
# [31]	train-mlogloss:0.68523	test-mlogloss:0.69218
# [32]	train-mlogloss:0.68497	test-mlogloss:0.69218
# [33]	train-mlogloss:0.68473	test-mlogloss:0.69216
# [34]	train-mlogloss:0.68453	test-mlogloss:0.69211
# [35]	train-mlogloss:0.68429	test-mlogloss:0.69208
# [36]	train-mlogloss:0.68401	test-mlogloss:0.69204
# [37]	train-mlogloss:0.68375	test-mlogloss:0.69199
# [38]	train-mlogloss:0.68351	test-mlogloss:0.69197
# [39]	train-mlogloss:0.68330	test-mlogloss:0.69195
# [40]	train-mlogloss:0.68307	test-mlogloss:0.69192
# [41]	train-mlogloss:0.68281	test-mlogloss:0.69187
# [193]	train-mlogloss:0.64908	test-mlogloss:0.69138
# [194]	train-mlogloss:0.64888	test-mlogloss:0.69137
# [195]	train-mlogloss:0.64864	test-mlogloss:0.69138
# [196]	train-mlogloss:0.64843	test-mlogloss:0.69138
# [197]	train-mlogloss:0.64821	test-mlogloss:0.69139
# [198]	train-mlogloss:0.64804	test-mlogloss:0.69138
# [199]	train-mlogloss:0.64785	test-mlogloss:0.69136
# [200]	train-mlogloss:0.64761	test-mlogloss:0.69135
# [201]	train-mlogloss:0.64739	test-mlogloss:0.69136
# [202]	train-mlogloss:0.64719	test-mlogloss:0.69137
# [[32443  9053]
#  [26547  7512]]
# Normalized confusion matrix
# [[0.78183439 0.21816561]
#  [0.77944156 0.22055844]]
# Feature importance (by weight): [('f73', 3449.0), ('f79', 3449.0), ('f37', 3290.0), ('f7', 3241.0), ('f40', 3041.0), ('f27', 2981.0), ('f94', 2959.0), ('f23', 2940.0), ('f71', 2914.0), ('f39', 2906.0), ('f87', 2880.0), ('f86', 2843.0), ('f6', 2836.0), ('f72', 2821.0), ('f22', 2817.0), ('f43', 2816.0), ('f35', 2803.0), ('f92', 2794.0), ('f3', 2787.0), ('f99', 2787.0), ('f85', 2734.0), ('f58', 2730.0), ('f32', 2713.0), ('f88', 2687.0), ('f69', 2648.0), ('f21', 2639.0), ('f57', 2615.0), ('f53', 2600.0), ('f76', 2529.0), ('f2', 2518.0), ('f65', 2512.0), ('f9', 2501.0), ('f80', 2499.0), ('f25', 2478.0), ('f81', 2469.0), ('f56', 2465.0), ('f42', 2456.0), ('f29', 2433.0), ('f47', 2428.0), ('f48', 2405.0), ('f10', 2393.0), ('f95', 2393.0), ('f4', 2359.0), ('f5', 2359.0), ('f70', 2349.0), ('f91', 2330.0), ('f49', 2326.0), ('f46', 2319.0), ('f90', 2305.0), ('f55', 2271.0), ('f63', 2236.0), ('f84', 2231.0), ('f62', 2221.0), ('f78', 2175.0), ('f18', 2168.0), ('f51', 2138.0), ('f34', 2127.0), ('f41', 2111.0), ('f16', 2100.0), ('f45', 2099.0), ('f82', 2096.0), ('f28', 2090.0), ('f83', 2063.0), ('f64', 2062.0), ('f1', 2052.0), ('f67', 2052.0), ('f96', 2044.0), ('f61', 2043.0), ('f60', 2033.0), ('f15', 2010.0), ('f13', 1965.0), ('f59', 1948.0), ('f89', 1939.0), ('f54', 1936.0), ('f44', 1918.0), ('f31', 1914.0), ('f52', 1896.0), ('f93', 1881.0), ('f75', 1878.0), ('f50', 1849.0), ('f38', 1835.0), ('f66', 1791.0), ('f14', 1757.0), ('f97', 1743.0), ('f74', 1741.0), ('f11', 1739.0), ('f68', 1720.0), ('f30', 1651.0), ('f98', 1647.0), ('f20', 1632.0), ('f0', 1630.0), ('f36', 1585.0), ('f19', 1574.0), ('f12', 1458.0), ('f17', 1346.0), ('f77', 1271.0), ('f24', 1230.0), ('f33', 1215.0), ('f8', 1204.0), ('f26', 1185.0)]

# %%
import os

# Below Code Gets Rid of Copy Of when making a copy of the models.
for filename in os.listdir(f'{googlepath}models/'):
    split = filename.split(" ")
    if len(split) == 2:
        os.rename(f'{googlepath}models/{filename}', f'{googlepath}models/{split[1]}')
    else:
        print("Nothing to rename.")

# Below Code Gets Rid of Checkpoint Number in Name
for filename in os.listdir(f'{googlepath}models/'):
    split = filename.split(".")
    if len(split) == 3:
        prefix, _, suffix = split
        new_name = prefix + "." + suffix
        os.rename(f'{googlepath}models/{filename}', f'{googlepath}models/{new_name}')
    elif filename == "clf.pkl":
        os.rename(f'{googlepath}models/{filename}', f'{googlepath}models/xgb')
    else:
        print("Nothing to rename.")
# Out:
# Nothing to rename.
# Nothing to rename.

# %% [markdown]
# ### Get the Predictions

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import joblib
import xgboost as xgb

tf.config.run_functions_eagerly(True)  # Enable eager execution

class Predict:
    def __init__(self, num_historical_days=20, days=10, pct_change=0,
                 gan_weights_path=f'{googlepath}models/gan.h5',
                 xgb_model_path=f'{googlepath}models/xgb'):
        self.num_historical_days = num_historical_days
        self.gan_weights_path = gan_weights_path
        self.xgb_model_path = xgb_model_path
        self.data = []

        # Check if the model files exist
        for model_path in [self.gan_weights_path, self.xgb_model_path]:
            if not os.path.exists(model_path):
                raise FileNotFoundError(f"No file found at {model_path}")

        # Load and preprocess stock data
        files = [os.path.join(f'{googlepath}stock_data', f) for f in os.listdir(f'{googlepath}stock_data')]
        for file in files:
            print(file)
            df = pd.read_csv(file, index_col='timestamp', parse_dates=True)
            df = df.sort_index(ascending=False)
            df = df[['open', 'high', 'low', 'close', 'volume']]
            df = ((df -
                   df.rolling(self.num_historical_days).mean().shift(-self.num_historical_days)) /
                  (df.rolling(self.num_historical_days).max().shift(-self.num_historical_days) -
                   df.rolling(self.num_historical_days).min().shift(-self.num_historical_days)))
            df = df.dropna()
            if len(df) >= self.num_historical_days + 200:
                self.data.append((file.split('/')[-1], df.index[0], df[200:200 + self.num_historical_days].values))

    def build_gan_model(self):
        """Rebuild the GAN model architecture."""
        model = GAN(num_features=5, num_historical_days=self.num_historical_days,
                    generator_input_size=200, is_train=False)
        return model

    def load_gan_model(self):
        """Load the GAN model and its weights."""
        gan = self.build_gan_model()
        try:
            # Initialize model to create the graph
            dummy_noise = tf.random.normal([1, 200])  # Adjust shape based on GAN architecture
            dummy_data = tf.random.normal([1, self.num_historical_days, 5])  # Adjust shape based on GAN architecture
            _ = gan((dummy_noise, dummy_data), training=False)  # Ensure the model is built and variables are created

            # Load weights now that the model is initialized
            gan.load_weights(self.gan_weights_path, by_name=True)  # Try loading weights by name
            print("GAN weights loaded successfully.")
            return gan
        except Exception as e:
            print(f"Error loading GAN weights: {e}")
            return None

    def load_xgb_model(self):
        """Load the XGBoost model."""
        try:
            clf = joblib.load(self.xgb_model_path)
            print("XGBoost model loaded successfully.")
            return clf
        except Exception as e:
            print(f"Error loading XGBoost model: {e}")
            return None

    def gan_predict(self):
        gan = self.load_gan_model()
        if gan is None:
            print("Invalid GAN model.")
            return

        clf = self.load_xgb_model()
        if clf is None:
            print("Invalid XGBoost model.")
            return

        for sym, date, data in self.data:
            # Prepare data for GAN prediction
            data = np.expand_dims(data, axis=0)  # Adding batch dimension
            noise = tf.random.normal([1, 200])  # Assuming noise_dim is 200
            generated_features = gan.generator.predict(noise)
            generated_features = generated_features.flatten().reshape(1, -1)  # Flatten and reshape for XGBoost

            features = xgb.DMatrix(generated_features)

            # Predict using XGBoost model
            prediction = clf.predict(features)
            print(f'{str(date).split(" ")[0]} {sym} Prediction: {prediction[0]}')

# Example usage
predictor = Predict(num_historical_days=HISTORICAL_DAYS_AMOUNT, days=DAYS_AHEAD, pct_change=PCT_CHANGE_AMOUNT)
predictor.gan_predict()
# Out:
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VNO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WSM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WWD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TXNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UNM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UMBF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WPC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UFPI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WSO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VMI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WTS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TTEK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/X.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VSH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WCC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UTHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TOL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TREX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/VAL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UBSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WTRG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/XRAY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ZION.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/THC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WTFC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SRPT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TPL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/WBS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/THG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/THO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SWX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TTC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SON.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SAM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/UGI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SLM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SLGN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SNV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RMBS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RRX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SEIC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RNR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RGLD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RGEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SIGI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RYN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SKX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SSB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ONTO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PRGO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/R.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/POWI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RLI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PII.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RBA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PAG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PCH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/TEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RRC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NNN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OLED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/RPM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NYT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OSK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NSP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OHI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PVH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NOV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/PPC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MTN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MTZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MSM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NLY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OPCH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/SSD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NJR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OLN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/OGE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NBIX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NEU.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MKSI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ONB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MIDD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MAT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MSA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ORI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MMS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/M.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NEOG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/NFG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LPX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MANH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MUR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LSTR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LSCC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MTG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KRC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/JEF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LANC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/MAN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LFUS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ITT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/IBOC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LNW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/IDA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LII.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KEX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KMPR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LECO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/KBH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GPK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/JLL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/INGR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GEF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GBCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LAD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GGG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HAE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/JWN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HXL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HOG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FCN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/HRB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GNTX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FNB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FLG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FLO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/LAMR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FCFS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EPR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FHN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FHI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EME.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EXPO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EGP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FIX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CRUS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EXP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/DINO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EWBC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/DCI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CUZ.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/DAR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FLS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CSL.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ELS.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/COLB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/FFIN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/COLM.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GATX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CDP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CLF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/EEFT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CMC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CXT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CHE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CASY.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CLH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CGNX.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/GAP.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CACI.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CIEN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CAR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CADE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CBT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/COHR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CFR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AGCO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BIO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CBSH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BDC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AVT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ATR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BCO.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CHDN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BKH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BYD.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/BMRN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AZPN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ASGN.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AMKR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ARWR.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AZTA.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ASH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/COKE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AMG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CHH.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ARW.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ADC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AMED.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AAON.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AFG.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ACHC.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ASB.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/CCK.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AIT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ALE.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AVNT.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ANF.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/ALV.csv
# drive/MyDrive/Colab Notebooks/Thesis_Project_GAN_Baseline_Sub_S&P400_SameTime/stock_data/AN.csv
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# GAN weights loaded successfully.
# XGBoost model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 VNO.csv Prediction: [0.51692027 0.4830797 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2024-10-28 WSM.csv Prediction: [0.49744883 0.50255114]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 2024-10-28 WWD.csv Prediction: [0.51883596 0.48116407]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2024-10-28 TXNM.csv Prediction: [0.5225896  0.47741038]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 UNM.csv Prediction: [0.52065057 0.47934946]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 WEN.csv Prediction: [0.5216992 0.4783008]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 UMBF.csv Prediction: [0.51411533 0.4858847 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 WPC.csv Prediction: [0.5096918 0.4903082]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 UFPI.csv Prediction: [0.5080078  0.49199215]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 VLY.csv Prediction: [0.50465214 0.49534786]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 WSO.csv Prediction: [0.50073016 0.4992698 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2024-10-28 VMI.csv Prediction: [0.49590755 0.50409245]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 WTS.csv Prediction: [0.5026412  0.49735877]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 TTEK.csv Prediction: [0.505164   0.49483597]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 TKR.csv Prediction: [0.50669754 0.49330246]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 X.csv Prediction: [0.50018615 0.49981388]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 VSH.csv Prediction: [0.51524895 0.48475105]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 WCC.csv Prediction: [0.5175386 0.4824614]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 WHR.csv Prediction: [0.5014893  0.49851072]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 UTHR.csv Prediction: [0.49262893 0.5073711 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 TOL.csv Prediction: [0.5134936  0.48650637]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 TREX.csv Prediction: [0.5058521 0.4941479]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 VAL.csv Prediction: [0.5026799  0.49732012]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 UBSI.csv Prediction: [0.4936474 0.5063526]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 WTRG.csv Prediction: [0.48236343 0.51763654]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 XRAY.csv Prediction: [0.50790143 0.49209854]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 ZION.csv Prediction: [0.52287894 0.47712106]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 THC.csv Prediction: [0.5124481  0.48755196]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 WTFC.csv Prediction: [0.5228587 0.4771413]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 SRPT.csv Prediction: [0.51036 0.48964]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 TPL.csv Prediction: [0.5081325  0.49186748]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2024-10-28 SF.csv Prediction: [0.49555564 0.50444436]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 WBS.csv Prediction: [0.52722734 0.4727726 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 THG.csv Prediction: [0.5222459 0.4777541]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 THO.csv Prediction: [0.50227666 0.4977233 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 SWX.csv Prediction: [0.5032347  0.49676532]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 SCI.csv Prediction: [0.51543933 0.48456067]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2024-10-28 TTC.csv Prediction: [0.5383765 0.4616235]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 SON.csv Prediction: [0.51941305 0.48058698]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2024-10-28 SAM.csv Prediction: [0.51694655 0.4830534 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 UGI.csv Prediction: [0.51396924 0.48603076]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 SLM.csv Prediction: [0.51463866 0.4853613 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 SLGN.csv Prediction: [0.511234   0.48876604]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2024-10-28 SR.csv Prediction: [0.4901789 0.5098211]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 SNV.csv Prediction: [0.51827407 0.48172593]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2024-10-28 RMBS.csv Prediction: [0.5159274  0.48407263]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2024-10-28 RRX.csv Prediction: [0.5224049  0.47759506]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2024-10-28 SEIC.csv Prediction: [0.5071495  0.49285045]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 RNR.csv Prediction: [0.5123556  0.48764437]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 RGLD.csv Prediction: [0.524268  0.4757321]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 RGEN.csv Prediction: [0.515708   0.48429197]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 SIGI.csv Prediction: [0.533081 0.466919]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 RYN.csv Prediction: [0.5184671  0.48153293]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 SMG.csv Prediction: [0.497809 0.502191]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 SKX.csv Prediction: [0.52989274 0.47010723]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 SSB.csv Prediction: [0.5073661  0.49263388]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 ONTO.csv Prediction: [0.51439786 0.48560217]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 PRGO.csv Prediction: [0.513002   0.48699802]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 R.csv Prediction: [0.5069281 0.4930719]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 POWI.csv Prediction: [0.51707447 0.4829255 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 RLI.csv Prediction: [0.5040132  0.49598682]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2024-10-28 PII.csv Prediction: [0.48255312 0.5174469 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2024-10-28 RS.csv Prediction: [0.5009257 0.4990743]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 RBA.csv Prediction: [0.5071192  0.49288085]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 PAG.csv Prediction: [0.49849632 0.5015037 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 PCH.csv Prediction: [0.529103   0.47089702]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 TEX.csv Prediction: [0.5149451 0.4850549]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 RRC.csv Prediction: [0.52215856 0.47784144]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 NNN.csv Prediction: [0.52953124 0.4704688 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 PB.csv Prediction: [0.49714792 0.5028521 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 OLED.csv Prediction: [0.50129324 0.49870673]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 RPM.csv Prediction: [0.5068925 0.4931075]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 NYT.csv Prediction: [0.5093411  0.49065888]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 OSK.csv Prediction: [0.52183044 0.4781696 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 NSP.csv Prediction: [0.48019072 0.51980925]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 OHI.csv Prediction: [0.5122086  0.48779145]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 PVH.csv Prediction: [0.501116   0.49888408]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 NOV.csv Prediction: [0.5023064  0.49769363]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 PPC.csv Prediction: [0.50537384 0.49462616]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 MTN.csv Prediction: [0.52134    0.47866002]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 MTZ.csv Prediction: [0.49680004 0.50319993]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 MSM.csv Prediction: [0.5082449  0.49175513]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 NLY.csv Prediction: [0.5155903 0.4844097]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 OPCH.csv Prediction: [0.5082499  0.49175012]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 SSD.csv Prediction: [0.512564   0.48743597]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 NJR.csv Prediction: [0.5077466 0.4922534]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 OLN.csv Prediction: [0.49814034 0.5018597 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 OGE.csv Prediction: [0.51616734 0.4838327 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 NBIX.csv Prediction: [0.51314694 0.4868531 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 NEU.csv Prediction: [0.5009731 0.4990269]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 MKSI.csv Prediction: [0.50769717 0.4923028 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 ONB.csv Prediction: [0.49913362 0.50086635]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 MIDD.csv Prediction: [0.5233499  0.47665006]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 MAT.csv Prediction: [0.5025175  0.49748248]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 MSA.csv Prediction: [0.51364636 0.48635367]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 ORI.csv Prediction: [0.4989149 0.5010851]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 MMS.csv Prediction: [0.5235036 0.4764964]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 KNX.csv Prediction: [0.49474573 0.50525427]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2024-10-28 M.csv Prediction: [0.513328   0.48667198]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 NEOG.csv Prediction: [0.5160195  0.48398048]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 NFG.csv Prediction: [0.4965398  0.50346017]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 LPX.csv Prediction: [0.49915946 0.50084054]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 MANH.csv Prediction: [0.51214755 0.48785242]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 MUR.csv Prediction: [0.47994334 0.5200566 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 LSTR.csv Prediction: [0.50182366 0.49817637]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 LSCC.csv Prediction: [0.4983657 0.5016343]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 MTG.csv Prediction: [0.49495277 0.50504726]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 KRC.csv Prediction: [0.49297044 0.5070296 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 JEF.csv Prediction: [0.5103576  0.48964244]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 LANC.csv Prediction: [0.5159416  0.48405835]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 MAN.csv Prediction: [0.52645034 0.4735497 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 LFUS.csv Prediction: [0.50877976 0.4912202 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 ITT.csv Prediction: [0.48337242 0.51662755]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 IBOC.csv Prediction: [0.4965768 0.5034232]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 LNW.csv Prediction: [0.5166222 0.4833778]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 IDA.csv Prediction: [0.49701965 0.50298035]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 HR.csv Prediction: [0.49915323 0.50084674]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 LII.csv Prediction: [0.51643604 0.48356396]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 GT.csv Prediction: [0.51693875 0.48306122]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 KEX.csv Prediction: [0.51411366 0.48588628]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 KMPR.csv Prediction: [0.5143529  0.48564708]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 LECO.csv Prediction: [0.49324724 0.5067528 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 KBH.csv Prediction: [0.5165836  0.48341638]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 GPK.csv Prediction: [0.514809   0.48519096]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 JLL.csv Prediction: [0.4977333 0.5022667]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 INGR.csv Prediction: [0.51880383 0.48119614]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 GEF.csv Prediction: [0.5104458  0.48955423]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2024-10-28 GHC.csv Prediction: [0.5103815  0.48961848]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 GBCI.csv Prediction: [0.529537 0.470463]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 LAD.csv Prediction: [0.5141238  0.48587626]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 GGG.csv Prediction: [0.51689786 0.4831021 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 HAE.csv Prediction: [0.50569224 0.49430773]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 FR.csv Prediction: [0.49278042 0.50721955]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 JWN.csv Prediction: [0.51494455 0.48505548]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 HXL.csv Prediction: [0.5184893 0.4815107]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 HOG.csv Prediction: [0.49758384 0.5024162 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 FCN.csv Prediction: [0.5241623  0.47583774]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 HRB.csv Prediction: [0.51317686 0.48682308]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 GNTX.csv Prediction: [0.4829664 0.5170336]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 FNB.csv Prediction: [0.5167856  0.48321438]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 FLG.csv Prediction: [0.49636242 0.50363755]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 FLO.csv Prediction: [0.5097768 0.4902232]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2024-10-28 LAMR.csv Prediction: [0.50178766 0.4982123 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 FCFS.csv Prediction: [0.5139158 0.4860842]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 EPR.csv Prediction: [0.5160755  0.48392454]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 2024-10-28 FHN.csv Prediction: [0.5139976  0.48600233]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 FHI.csv Prediction: [0.5169704 0.4830296]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 EME.csv Prediction: [0.50272524 0.49727473]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 EXPO.csv Prediction: [0.4987643  0.50123566]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 EGP.csv Prediction: [0.5054909  0.49450913]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2024-10-28 FIX.csv Prediction: [0.483984 0.516016]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 CRUS.csv Prediction: [0.5065294  0.49347064]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 EXP.csv Prediction: [0.50092125 0.49907875]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 DINO.csv Prediction: [0.51548016 0.48451984]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 EWBC.csv Prediction: [0.5159968 0.4840032]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 DCI.csv Prediction: [0.501871   0.49812904]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CUZ.csv Prediction: [0.5112745  0.48872548]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 DAR.csv Prediction: [0.51479524 0.48520476]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 FLS.csv Prediction: [0.5033222  0.49667782]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 CSL.csv Prediction: [0.50011617 0.4998838 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 ELS.csv Prediction: [0.5016659  0.49833414]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 COLB.csv Prediction: [0.5221313 0.4778687]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 FFIN.csv Prediction: [0.5176956  0.48230436]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 COLM.csv Prediction: [0.5171162  0.48288378]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CNX.csv Prediction: [0.48952845 0.5104715 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 GATX.csv Prediction: [0.47841424 0.5215858 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CDP.csv Prediction: [0.5173719 0.4826281]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CLF.csv Prediction: [0.5130129 0.4869871]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CW.csv Prediction: [0.49946934 0.50053066]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 EEFT.csv Prediction: [0.502269 0.497731]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 CMC.csv Prediction: [0.5131395  0.48686054]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CXT.csv Prediction: [0.52057856 0.47942144]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 CHE.csv Prediction: [0.50657487 0.49342513]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CASY.csv Prediction: [0.5233382  0.47666183]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 CLH.csv Prediction: [0.50811845 0.49188158]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 CGNX.csv Prediction: [0.49755862 0.50244135]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 GAP.csv Prediction: [0.5067551 0.4932449]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CACI.csv Prediction: [0.49855343 0.5014466 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2024-10-28 CIEN.csv Prediction: [0.52296364 0.4770364 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 CAR.csv Prediction: [0.5163184  0.48368162]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 CADE.csv Prediction: [0.5177863  0.48221365]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 CBT.csv Prediction: [0.4904827 0.5095173]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 COHR.csv Prediction: [0.51466566 0.48533428]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 CFR.csv Prediction: [0.4962966  0.50370336]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 AGCO.csv Prediction: [0.48198622 0.5180138 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 BIO.csv Prediction: [0.50453144 0.4954686 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 BC.csv Prediction: [0.4961344 0.5038656]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CBSH.csv Prediction: [0.50655746 0.49344257]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 BDC.csv Prediction: [0.49626806 0.5037319 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 AVT.csv Prediction: [0.51267177 0.4873282 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 ATR.csv Prediction: [0.4992399 0.5007601]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2024-10-28 BCO.csv Prediction: [0.4941992  0.50580084]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 CHDN.csv Prediction: [0.5169219 0.4830781]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 BKH.csv Prediction: [0.5179169  0.48208305]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 BYD.csv Prediction: [0.50965977 0.49034026]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 BMRN.csv Prediction: [0.49391073 0.50608927]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 AZPN.csv Prediction: [0.5006135 0.4993865]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 ASGN.csv Prediction: [0.47856474 0.5214353 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 AMKR.csv Prediction: [0.4944744 0.5055256]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 ARWR.csv Prediction: [0.4902567  0.50974333]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 AZTA.csv Prediction: [0.503833 0.496167]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 ASH.csv Prediction: [0.512305 0.487695]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 COKE.csv Prediction: [0.51122826 0.48877168]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 AMG.csv Prediction: [0.521664 0.478336]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2024-10-28 CHH.csv Prediction: [0.49216363 0.5078364 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 ARW.csv Prediction: [0.49517265 0.5048273 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 ADC.csv Prediction: [0.50141466 0.4985853 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 AMED.csv Prediction: [0.5331881  0.46681193]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 AAON.csv Prediction: [0.50734764 0.4926523 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 AFG.csv Prediction: [0.52195036 0.47804958]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 ACHC.csv Prediction: [0.49540025 0.5045997 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 ASB.csv Prediction: [0.5131262 0.4868738]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 CCK.csv Prediction: [0.5020644  0.49793556]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 AIT.csv Prediction: [0.507339 0.492661]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 ALE.csv Prediction: [0.490371 0.509629]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 AVNT.csv Prediction: [0.49390453 0.5060955 ]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2024-10-28 ANF.csv Prediction: [0.5147182  0.48528183]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 ALV.csv Prediction: [0.5229366  0.47706342]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2024-10-28 AN.csv Prediction: [0.49450094 0.5054991 ]
